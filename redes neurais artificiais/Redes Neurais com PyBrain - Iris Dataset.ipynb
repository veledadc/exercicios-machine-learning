# %%
import numpy as np

# carregando os dados com numpy
entradas = np.genfromtxt('iris.data', delimiter=',', usecols=(0,1,2,3))
saidas = np.genfromtxt('iris.data', delimiter=',', usecols=(4))
print(len(entradas))
print(len(saidas))
# Out:
# 150
# 150

# %%
'''
Iris-setosa: 0
Iris-versicolor: 1
Iris-virginica: 2
'''

# mostrando as 5 primeiras amostras que são Iris-setosa
print(entradas[:5])
print(saidas[:5])

print('---------------------')

# mostrando as 5 últimas amostras que são de Iris-virginica
print(entradas[-5:])
print(saidas[-5:])
# Out:
# [[5.1 3.5 1.4 0.2]
#  [4.9 3.  1.4 0.2]
#  [4.7 3.2 1.3 0.2]
#  [4.6 3.1 1.5 0.2]
#  [5.  3.6 1.4 0.2]]
# [0. 0. 0. 0. 0.]
# ---------------------
# [[6.7 3.  5.2 2.3]
#  [6.3 2.5 5.  1.9]
#  [6.5 3.  5.2 2. ]
#  [6.2 3.4 5.4 2.3]
#  [5.9 3.  5.1 1.8]]
# [2. 2. 2. 2. 2.]

# %%
# vou utilizar 105 amostras para treino sendo 35 de cada classe
entradas_treino = np.concatenate((entradas[:35], entradas[50:85], entradas[100:135]))
saidas_treino = np.concatenate((saidas[:35], saidas[50:85], saidas[100:135]))
print(len(entradas_treino))
print(len(saidas_treino))
# Out:
# 105
# 105

# %%
entradas_teste = np.concatenate((entradas[35:50], entradas[85:100], entradas[135:]))
saidas_teste = np.concatenate((saidas[35:50], saidas[85:100], saidas[135:]))
print(len(entradas_teste))
print(len(saidas_teste))
# Out:
# 45
# 45

# %%
from pybrain.datasets import SupervisedDataSet
from pybrain.tools.shortcuts import buildNetwork
from pybrain.supervised import BackpropTrainer

# %%
treinamento = SupervisedDataSet(4, 1)
for i in range(len(entradas_treino)):
    treinamento.addSample(entradas_treino[i], saidas_treino[i])
print(len(treinamento))
print(treinamento.indim)
print(treinamento.outdim)
# Out:
# 105
# 4
# 1

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.3)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[0.012 ]')
# ('correct:', '[0     ]')
# error:  0.00006914
# ('out:    ', '[0.006 ]')
# ('correct:', '[0     ]')
# error:  0.00001682
# ('out:    ', '[0.018 ]')
# ('correct:', '[0     ]')
# error:  0.00015423
# ('out:    ', '[0.024 ]')
# ('correct:', '[0     ]')
# error:  0.00028195
# ('out:    ', '[0.013 ]')
# ('correct:', '[0     ]')
# error:  0.00008374
# ('out:    ', '[0.011 ]')
# ('correct:', '[0     ]')
# error:  0.00005977
# ('out:    ', '[0.061 ]')
# ('correct:', '[0     ]')
# error:  0.00185809
# ('out:    ', '[0.018 ]')
# ('correct:', '[0     ]')
# error:  0.00016594
# ('out:    ', '[0.032 ]')
# ('correct:', '[0     ]')
# error:  0.00049799
# ('out:    ', '[0.02  ]')
# ('correct:', '[0     ]')
# error:  0.00020304
# ('out:    ', '[0.028 ]')
# ('correct:', '[0     ]')
# error:  0.00038624
# ('out:    ', '[0.008 ]')
# ('correct:', '[0     ]')
# error:  0.00002873
# ('out:    ', '[0.019 ]')
# ('correct:', '[0     ]')
# error:  0.00018146
# ('out:    ', '[0.007 ]')
# ('correct:', '[0     ]')
# error:  0.00002209
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00009339
# ('out:    ', '[1.083 ]')
# ('correct:', '[1     ]')
# error:  0.00346720
# ('out:    ', '[1.14  ]')
# ('correct:', '[1     ]')
# error:  0.00982724
# ('out:    ', '[1.309 ]')
# ('correct:', '[1     ]')
# error:  0.04759358
# ('out:    ', '[0.908 ]')
# ('correct:', '[1     ]')
# error:  0.00420242
# ('out:    ', '[1.137 ]')
# ('correct:', '[1     ]')
# error:  0.00932685
# ('out:    ', '[1.206 ]')
# ('correct:', '[1     ]')
# error:  0.02117372
# ('out:    ', '[1.161 ]')
# ('correct:', '[1     ]')
# error:  0.01302588
# ('out:    ', '[0.949 ]')
# ('correct:', '[1     ]')
# error:  0.00130840
# ('out:    ', '[0.732 ]')
# ('correct:', '[1     ]')
# error:  0.03597381
# ('out:    ', '[1.117 ]')
# ('correct:', '[1     ]')
# error:  0.00678671
# ('out:    ', '[0.861 ]')
# ('correct:', '[1     ]')
# error:  0.00970486
# ('out:    ', '[0.994 ]')
# ('correct:', '[1     ]')
# error:  0.00001989
# ('out:    ', '[0.959 ]')
# ('correct:', '[1     ]')
# error:  0.00082981
# ('out:    ', '[0.571 ]')
# ('correct:', '[1     ]')
# error:  0.09188109
# ('out:    ', '[0.995 ]')
# ('correct:', '[1     ]')
# error:  0.00001221
# ('out:    ', '[2.037 ]')
# ('correct:', '[2     ]')
# error:  0.00067272
# ('out:    ', '[1.984 ]')
# ('correct:', '[2     ]')
# error:  0.00012129
# ('out:    ', '[1.765 ]')
# ('correct:', '[2     ]')
# error:  0.02753602
# ('out:    ', '[1.587 ]')
# ('correct:', '[2     ]')
# error:  0.08527027
# ('out:    ', '[1.837 ]')
# ('correct:', '[2     ]')
# error:  0.01333129
# ('out:    ', '[2.018 ]')
# ('correct:', '[2     ]')
# error:  0.00016782
# ('out:    ', '[1.844 ]')
# ('correct:', '[2     ]')
# error:  0.01209819
# ('out:    ', '[1.881 ]')
# ('correct:', '[2     ]')
# error:  0.00703712
# ('out:    ', '[2.018 ]')
# ('correct:', '[2     ]')
# error:  0.00017095
# ('out:    ', '[2.029 ]')
# ('correct:', '[2     ]')
# error:  0.00040942
# ('out:    ', '[1.919 ]')
# ('correct:', '[2     ]')
# error:  0.00330308
# ('out:    ', '[1.864 ]')
# ('correct:', '[2     ]')
# error:  0.00927724
# ('out:    ', '[1.797 ]')
# ('correct:', '[2     ]')
# error:  0.02059098
# ('out:    ', '[1.908 ]')
# ('correct:', '[2     ]')
# error:  0.00425682
# ('out:    ', '[1.719 ]')
# ('correct:', '[2     ]')
# error:  0.03939592
# ('All errors:', [6.913929808113951e-05, 1.6817505222213608e-05, 0.00015423081987789083, 0.00028194664558079996, 8.373688686422157e-05, 5.9771076241389254e-05, 0.0018580885792958792, 0.00016594027144881465, 0.0004979901765779838, 0.0002030383040613488, 0.00038623819643340677, 2.8733593882401414e-05, 0.00018145642272204235, 2.2085881855342763e-05, 9.339156553776709e-05, 0.00346719742149256, 0.009827240443760618, 0.047593583973853, 0.004202420984312971, 0.009326848201929085, 0.021173716108369954, 0.01302588004185912, 0.0013083962229437618, 0.03597380665838429, 0.0067867125477716625, 0.009704863153938715, 1.988962763681978e-05, 0.0008298084969245381, 0.0918810856719451, 1.2211095874025086e-05, 0.0006727244503387128, 0.00012129200868090113, 0.027536016293160548, 0.08527027347497039, 0.013331288649983009, 0.00016782168424156937, 0.012098191326625395, 0.007037118877953463, 0.00017094575089295424, 0.0004094180025764723, 0.0033030768320763343, 0.009277241070222469, 0.020590983893944367, 0.004256817353451789, 0.03939592061728989])
# ('Average error:', 0.010730564359135268)
# ('Max error:', 0.0918810856719451, 'Median error:', 0.0013083962229437618)
# 0.010730564359135268

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.005, momentum=0.5)

# treinando a rede
for epoca in range(2000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[-0.002]')
# ('correct:', '[0     ]')
# error:  0.00000170
# ('out:    ', '[-0.012]')
# ('correct:', '[0     ]')
# error:  0.00007384
# ('out:    ', '[0.007 ]')
# ('correct:', '[0     ]')
# error:  0.00002396
# ('out:    ', '[0.016 ]')
# ('correct:', '[0     ]')
# error:  0.00012458
# ('out:    ', '[-0.002]')
# ('correct:', '[0     ]')
# error:  0.00000149
# ('out:    ', '[-0.005]')
# ('correct:', '[0     ]')
# error:  0.00001276
# ('out:    ', '[0.058 ]')
# ('correct:', '[0     ]')
# error:  0.00166128
# ('out:    ', '[0.008 ]')
# ('correct:', '[0     ]')
# error:  0.00003453
# ('out:    ', '[0.015 ]')
# ('correct:', '[0     ]')
# error:  0.00011473
# ('out:    ', '[0.003 ]')
# ('correct:', '[0     ]')
# error:  0.00000451
# ('out:    ', '[0.017 ]')
# ('correct:', '[0     ]')
# error:  0.00014833
# ('out:    ', '[-0.01 ]')
# ('correct:', '[0     ]')
# error:  0.00004853
# ('out:    ', '[0.008 ]')
# ('correct:', '[0     ]')
# error:  0.00003511
# ('out:    ', '[-0.011]')
# ('correct:', '[0     ]')
# error:  0.00006322
# ('out:    ', '[-0    ]')
# ('correct:', '[0     ]')
# error:  0.00000000
# ('out:    ', '[0.926 ]')
# ('correct:', '[1     ]')
# error:  0.00272499
# ('out:    ', '[0.966 ]')
# ('correct:', '[1     ]')
# error:  0.00056373
# ('out:    ', '[1.139 ]')
# ('correct:', '[1     ]')
# error:  0.00970370
# ('out:    ', '[0.772 ]')
# ('correct:', '[1     ]')
# error:  0.02592545
# ('out:    ', '[0.988 ]')
# ('correct:', '[1     ]')
# error:  0.00007684
# ('out:    ', '[1.052 ]')
# ('correct:', '[1     ]')
# error:  0.00136125
# ('out:    ', '[0.997 ]')
# ('correct:', '[1     ]')
# error:  0.00000413
# ('out:    ', '[0.807 ]')
# ('correct:', '[1     ]')
# error:  0.01870206
# ('out:    ', '[0.63  ]')
# ('correct:', '[1     ]')
# error:  0.06849114
# ('out:    ', '[0.965 ]')
# ('correct:', '[1     ]')
# error:  0.00060317
# ('out:    ', '[0.727 ]')
# ('correct:', '[1     ]')
# error:  0.03723636
# ('out:    ', '[0.848 ]')
# ('correct:', '[1     ]')
# error:  0.01151472
# ('out:    ', '[0.808 ]')
# ('correct:', '[1     ]')
# error:  0.01848843
# ('out:    ', '[0.488 ]')
# ('correct:', '[1     ]')
# error:  0.13089440
# ('out:    ', '[0.85  ]')
# ('correct:', '[1     ]')
# error:  0.01123484
# ('out:    ', '[1.96  ]')
# ('correct:', '[2     ]')
# error:  0.00080390
# ('out:    ', '[1.903 ]')
# ('correct:', '[2     ]')
# error:  0.00465847
# ('out:    ', '[1.63  ]')
# ('correct:', '[2     ]')
# error:  0.06861555
# ('out:    ', '[1.435 ]')
# ('correct:', '[2     ]')
# error:  0.15934807
# ('out:    ', '[1.709 ]')
# ('correct:', '[2     ]')
# error:  0.04237694
# ('out:    ', '[1.946 ]')
# ('correct:', '[2     ]')
# error:  0.00147476
# ('out:    ', '[1.72  ]')
# ('correct:', '[2     ]')
# error:  0.03931964
# ('out:    ', '[1.784 ]')
# ('correct:', '[2     ]')
# error:  0.02335694
# ('out:    ', '[1.944 ]')
# ('correct:', '[2     ]')
# error:  0.00155368
# ('out:    ', '[1.958 ]')
# ('correct:', '[2     ]')
# error:  0.00087330
# ('out:    ', '[1.815 ]')
# ('correct:', '[2     ]')
# error:  0.01702332
# ('out:    ', '[1.755 ]')
# ('correct:', '[2     ]')
# error:  0.02994986
# ('out:    ', '[1.667 ]')
# ('correct:', '[2     ]')
# error:  0.05530623
# ('out:    ', '[1.806 ]')
# ('correct:', '[2     ]')
# error:  0.01874668
# ('out:    ', '[1.585 ]')
# ('correct:', '[2     ]')
# error:  0.08596515
# ('All errors:', [1.6951009628435154e-06, 7.38357511942684e-05, 2.3960717308777278e-05, 0.00012458132940221903, 1.4936729233099852e-06, 1.2763862621424193e-05, 0.0016612827037719659, 3.453459076423398e-05, 0.00011473350143379152, 4.508806193834241e-06, 0.00014833274899429894, 4.852515021550316e-05, 3.511003228148748e-05, 6.321785995237273e-05, 6.713607590575397e-10, 0.0027249914048662702, 0.0005637348631582033, 0.009703700732946756, 0.025925454754766927, 7.684232753941827e-05, 0.0013612527058424605, 4.1300448183129185e-06, 0.018702063029515742, 0.06849113927875262, 0.0006031686897014607, 0.037236358084636156, 0.011514722770267381, 0.018488429405556506, 0.1308943998446503, 0.011234836259810702, 0.0008039012351354119, 0.004658470337850597, 0.068615553844846, 0.15934806573821475, 0.04237694338334788, 0.0014747557494669777, 0.03931963707669382, 0.023356941534289365, 0.0015536828684208084, 0.0008733036715698451, 0.017023318132782378, 0.029949860297298913, 0.05530623400055272, 0.018746681722155406, 0.08596515249377716])
# ('Average error:', 0.019761028950724718)
# ('Max error:', 0.15934806573821475, 'Median error:', 0.0015536828684208084)
# 0.019761028950724718

# %%
# construindo a rede
rede = buildNetwork(treinamento.indim, 2, treinamento.outdim, bias=True)
trainer = BackpropTrainer(rede, treinamento, learningrate=0.01, momentum=0.7)

# treinando a rede
for epoca in range(1000):
    trainer.train()
    
# testando a rede
teste = SupervisedDataSet(4, 1)
for i in range(len(entradas_teste)):
    teste.addSample(entradas_teste[i], saidas_teste[i])
trainer.testOnData(teste, verbose=True)
# Out:
# Testing on data:
# ('out:    ', '[-0.029]')
# ('correct:', '[0     ]')
# error:  0.00041629
# ('out:    ', '[-0.044]')
# ('correct:', '[0     ]')
# error:  0.00097455
# ('out:    ', '[-0    ]')
# ('correct:', '[0     ]')
# error:  0.00000001
# ('out:    ', '[-0.003]')
# ('correct:', '[0     ]')
# error:  0.00000414
# ('out:    ', '[-0.023]')
# ('correct:', '[0     ]')
# error:  0.00026098
# ('out:    ', '[-0.04 ]')
# ('correct:', '[0     ]')
# error:  0.00081586
# ('out:    ', '[0.139 ]')
# ('correct:', '[0     ]')
# error:  0.00960502
# ('out:    ', '[-0.025]')
# ('correct:', '[0     ]')
# error:  0.00030746
# ('out:    ', '[0.014 ]')
# ('correct:', '[0     ]')
# error:  0.00009758
# ('out:    ', '[-0.012]')
# ('correct:', '[0     ]')
# error:  0.00006722
# ('out:    ', '[0.024 ]')
# ('correct:', '[0     ]')
# error:  0.00027632
# ('out:    ', '[-0.05 ]')
# ('correct:', '[0     ]')
# error:  0.00122975
# ('out:    ', '[-0.015]')
# ('correct:', '[0     ]')
# error:  0.00010527
# ('out:    ', '[-0.047]')
# ('correct:', '[0     ]')
# error:  0.00112730
# ('out:    ', '[-0.022]')
# ('correct:', '[0     ]')
# error:  0.00024292
# ('out:    ', '[0.976 ]')
# ('correct:', '[1     ]')
# error:  0.00027900
# ('out:    ', '[0.98  ]')
# ('correct:', '[1     ]')
# error:  0.00019953
# ('out:    ', '[1.088 ]')
# ('correct:', '[1     ]')
# error:  0.00390581
# ('out:    ', '[0.898 ]')
# ('correct:', '[1     ]')
# error:  0.00518413
# ('out:    ', '[1.024 ]')
# ('correct:', '[1     ]')
# error:  0.00028668
# ('out:    ', '[1.145 ]')
# ('correct:', '[1     ]')
# error:  0.01055405
# ('out:    ', '[1.04  ]')
# ('correct:', '[1     ]')
# error:  0.00081473
# ('out:    ', '[0.917 ]')
# ('correct:', '[1     ]')
# error:  0.00347762
# ('out:    ', '[0.82  ]')
# ('correct:', '[1     ]')
# error:  0.01612983
# ('out:    ', '[1.024 ]')
# ('correct:', '[1     ]')
# error:  0.00029015
# ('out:    ', '[0.888 ]')
# ('correct:', '[1     ]')
# error:  0.00627741
# ('out:    ', '[0.944 ]')
# ('correct:', '[1     ]')
# error:  0.00155581
# ('out:    ', '[0.918 ]')
# ('correct:', '[1     ]')
# error:  0.00337586
# ('out:    ', '[0.73  ]')
# ('correct:', '[1     ]')
# error:  0.03649449
# ('out:    ', '[0.938 ]')
# ('correct:', '[1     ]')
# error:  0.00191558
# ('out:    ', '[1.964 ]')
# ('correct:', '[2     ]')
# error:  0.00064074
# ('out:    ', '[1.98  ]')
# ('correct:', '[2     ]')
# error:  0.00020903
# ('out:    ', '[1.806 ]')
# ('correct:', '[2     ]')
# error:  0.01874167
# ('out:    ', '[1.523 ]')
# ('correct:', '[2     ]')
# error:  0.11355050
# ('out:    ', '[1.772 ]')
# ('correct:', '[2     ]')
# error:  0.02610214
# ('out:    ', '[1.98  ]')
# ('correct:', '[2     ]')
# error:  0.00020440
# ('out:    ', '[1.717 ]')
# ('correct:', '[2     ]')
# error:  0.04001653
# ('out:    ', '[1.929 ]')
# ('correct:', '[2     ]')
# error:  0.00249887
# ('out:    ', '[1.989 ]')
# ('correct:', '[2     ]')
# error:  0.00006399
# ('out:    ', '[1.988 ]')
# ('correct:', '[2     ]')
# error:  0.00007166
# ('out:    ', '[1.868 ]')
# ('correct:', '[2     ]')
# error:  0.00870343
# ('out:    ', '[1.846 ]')
# ('correct:', '[2     ]')
# error:  0.01187624
# ('out:    ', '[1.765 ]')
# ('correct:', '[2     ]')
# error:  0.02755270
# ('out:    ', '[1.932 ]')
# ('correct:', '[2     ]')
# error:  0.00234505
# ('out:    ', '[1.779 ]')
# ('correct:', '[2     ]')
# error:  0.02452146
# ('All errors:', [0.0004162880062609109, 0.0009745488491144998, 9.588152565510301e-09, 4.1425702715130735e-06, 0.0002609788047897136, 0.0008158603310515521, 0.009605023387431648, 0.00030745531536900596, 9.758100523082055e-05, 6.721588368339367e-05, 0.00027631874974255765, 0.001229747731440537, 0.00010527429482929129, 0.001127299489061024, 0.0002429204766359154, 0.00027900061528761893, 0.0001995330998100932, 0.0039058112414415507, 0.005184131442179005, 0.000286680820816929, 0.010554049381105286, 0.0008147286697551375, 0.003477621761670913, 0.016129829327294613, 0.0002901548536457149, 0.006277411892833332, 0.0015558105154956565, 0.003375856002764747, 0.03649449467749462, 0.0019155813180144754, 0.0006407424322337768, 0.00020902987650320588, 0.018741668641644962, 0.11355049675949158, 0.026102135428264506, 0.00020440448579971484, 0.04001652513670756, 0.0024988664381122355, 6.398618345271665e-05, 7.166056439361508e-05, 0.008703432575841986, 0.011876239487064283, 0.027552701710691456, 0.0023450545839242697, 0.024521461241460773])
# ('Average error:', 0.008519328125516918)
# ('Max error:', 0.11355049675949158, 'Median error:', 0.001127299489061024)
# 0.008519328125516918
