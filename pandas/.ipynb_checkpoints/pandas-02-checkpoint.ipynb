# %%
import pandas as pd

# %%
df = pd.DataFrame(
    [['fchollet/keras', 11302], ['openai/universe', 4350], ['pandas-dev/pandas', 8168]]
)

# %%
#tamanho do Data Frame (linhas, colunas)
df.shape
# Out:
# (3, 2)

# %%
df
# Out:
#                    0      1
# 0     fchollet/keras  11302
# 1    openai/universe   4350
# 2  pandas-dev/pandas   8168

# %%
df = pd.DataFrame(
    [['fchollet/keras', 11302], ['openai/universe', 4350], ['pandas-dev/pandas', 8168]],
    columns=['repository', 'stars']
)

# %%
df
# Out:
#           repository  stars
# 0     fchollet/keras  11302
# 1    openai/universe   4350
# 2  pandas-dev/pandas   8168

# %%
#errop proposital para buscar nome da coluna e não o idx
df[0]

# %%
df['stars']
# Out:
# 0    11302
# 1     4350
# 2     8168
# Name: stars, dtype: int64

# %%
df['repository']
# Out:
# 0       fchollet/keras
# 1      openai/universe
# 2    pandas-dev/pandas
# Name: repository, dtype: object

# %%
#media
df['stars'].mean()
# Out:
# 7940.0

# %%
#media ordenada
df['stars'].median()
# Out:
# 8168.0

# %%
#valor específico 
df.iloc[1]
# Out:
# repository    openai/universe
# stars                    4350
# Name: 1, dtype: object

# %%
df.iloc[1]['stars']
# Out:
# 4350
