# %%
import pandas as pd
import numpy as np

# %%
dados = {
    'nome': ['João', 'Maria', 'José', np.nan, 'Pedro', 'Judas', 'Tiago'],
    'sexo': ['M', 'F', 'M', np.nan, 'M', 'M', np.nan],
    'idade': [14, 13, np.nan, np.nan, 15, 13, 14],
    'nota': [4, 10, 7, np.nan, 8, 9, 7]
}
df = pd.DataFrame(dados)

# %%
df
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 3    NaN  NaN    NaN   NaN
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
#exclui linhas com NaN's
df.dropna()
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0

# %%
#exclui linhas com NaN's em todos os valores
df.dropna(how='all')
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
df['serie'] = np.nan

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 3    NaN  NaN    NaN   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
#exclui colunas com NaN's
df.dropna(how='all', axis=1)
# Out:
#     nome sexo  idade  nota
# 0   João    M   14.0   4.0
# 1  Maria    F   13.0  10.0
# 2   José    M    NaN   7.0
# 3    NaN  NaN    NaN   NaN
# 4  Pedro    M   15.0   8.0
# 5  Judas    M   13.0   9.0
# 6  Tiago  NaN   14.0   7.0

# %%
#exclui linhas com 3 NaN's
df.dropna(thresh=3)
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
df['serie'].fillna(8, inplace=True)

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    8.0
# 1  Maria    F   13.0  10.0    8.0
# 2   José    M    NaN   7.0    8.0
# 3    NaN  NaN    NaN   NaN    8.0
# 4  Pedro    M   15.0   8.0    8.0
# 5  Judas    M   13.0   9.0    8.0
# 6  Tiago  NaN   14.0   7.0    8.0

# %%
df['serie'] = np.nan

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M    NaN   7.0    NaN
# 3    NaN  NaN    NaN   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
df['idade'].mean()
# Out:
# 13.8

# %%
#Preencher com a media nos NaN's
df['idade'].fillna(df['idade'].mean(), inplace=True)

# %%
df
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M   13.8   7.0    NaN
# 3    NaN  NaN   13.8   NaN    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
# 6  Tiago  NaN   14.0   7.0    NaN

# %%
#excluir linhas que estã ocom sexo NaN
df[df['nome'].notnull() & df['sexo'].notnull()]
# Out:
#     nome sexo  idade  nota  serie
# 0   João    M   14.0   4.0    NaN
# 1  Maria    F   13.0  10.0    NaN
# 2   José    M   13.8   7.0    NaN
# 4  Pedro    M   15.0   8.0    NaN
# 5  Judas    M   13.0   9.0    NaN
